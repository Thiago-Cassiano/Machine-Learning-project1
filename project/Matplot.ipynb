# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
rng = np.random.default_rng()
rng.random(10), rng.integers(0, 10, size=5)
# Out:
# (array([0.08294596, 0.81911074, 0.41886775, 0.43279087, 0.77086339,
#         0.8909284 , 0.3752556 , 0.69616027, 0.48149682, 0.00885459]),
#  array([6, 2, 0, 0, 1], dtype=int64))

# %%
rng_seed = np.random.default_rng(seed=43)
rng_seed.random((3,3))
# Out:
# array([[0.65229926, 0.04377532, 0.02002959],
#        [0.83921258, 0.58714305, 0.22470523],
#        [0.75179227, 0.2636922 , 0.41997791]])

# %%
plt.plot();

# %%
plt.plot([1,2,3], [4,5,6])

# %%
x = [20,19,18]
y = [15,16,17]
plt.plot(x,y);

# %%
fig, ax = plt.subplots()
ax.plot(x,[50,100,250])

# %%
lp = np.linspace(0, 10, 100)
lp
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
# Line
fig, ax = plt.subplots()
ax.plot(lp, lp**2);

# %%
# Scatter
fig, ax = plt.subplots()
ax.scatter(lp, np.exp(lp));

# %%
fig, ax = plt.subplots()
ax.scatter(lp, np.sin(lp))

# %%
# Creating from dictionaries
nut_butter_prices = {'Almond butter': 10,
                     'Peanut butter': 8,
                     'Cashew butter': 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax.set(title = "My Nut Butter Store", ylabel='Price');

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));

# %%
h = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(h);

# %%
# Subplots options
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                             ncols=2,
                                             figsize=(10,5))
# plot to each axis
ax1.plot(x,x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax4.hist(np.random.randn(1000));
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-95c61c64da52> in <module>
#       4                                              figsize=(10,5))
#       5 # plot to each axis
# ----> 6 ax1.plot(x,x/2);
#       7 ax2.scatter(np.random.random(10), np.random.random(10));
#       8 ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
#
# TypeError: unsupported operand type(s) for /: 'list' and 'int'

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('1/1/2020', periods=1000))
ts = ts.cumsum()
ts.plot();

# %%
car = pd.read_csv('data/car-sales.csv')
car
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car['Price'] = car['Price'].str.replace('[\$\,\.]', '')
# Out:
# <ipython-input-31-2be65834c782>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car['Price'] = car['Price'].str.replace('[\$\,\.]', '')

# %%
car['Price']=car['Price'].str[:-2]

# %%
car['Sale Date'] = pd.date_range('1/1/2020', periods=len(car))

# %%
car['Total Sales'] = car['Price'].astype(int).cumsum() #Changed type only in this operation

# %%
car['Price'] = car['Price'].astype(int)

# %%
car
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car.plot(x='Sale Date', y='Total Sales');

# %%
car.plot(x='Odometer (KM)', y='Price', kind='scatter');

# %%
df = pd.DataFrame(rng.random((10, 4), float),columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.339140  0.291821  0.590837  0.310174
# 1  0.687645  0.630886  0.705469  0.612737
# 2  0.201773  0.236645  0.897596  0.857422
# 3  0.097489  0.826897  0.844117  0.240587
# 4  0.913542  0.885913  0.641652  0.047857
# 5  0.267401  0.833800  0.002487  0.310982
# 6  0.489281  0.057498  0.100933  0.181752
# 7  0.480374  0.644224  0.713995  0.752271
# 8  0.869420  0.316108  0.577307  0.486915
# 9  0.731528  0.803791  0.429375  0.152608

# %%
df.plot.bar();

# %%
car.plot(x='Make', y='Odometer (KM)', kind='bar');

# %%
car['Odometer (KM)'].plot.hist(bins=15);

# %%
heart_diseases = pd.read_csv('data/heart-disease.csv')
heart_diseases.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_diseases['age'].plot.hist(bins=15);

# %%
heart_diseases.plot.hist(figsize=(10,30), subplots=True);

# %%
#Pyplot Method
over_50 = heart_diseases[heart_diseases['age']>50]
over_50.plot(kind='scatter',
             x='age',
             y='chol',
             c='target',
             figsize=(10,6));

# %%
# OO (Object Oriented ) Method with pyplot
fig, ax = plt.subplots(figsize=(10,6))
over_50.plot(kind='scatter',
             x='age',
             y='chol',
             c='target',
             ax=ax)

#ax.set_xlim([45,100]) #widen the x axis limit
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
# OO Method from scratch
fig, ax = plt.subplots(figsize=(10,6))

scatter = ax.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target'])

ax.set(title='Heart disease and Cholesterol leves',
       xlabel='Age',
       ylabel='Cholesterol')

# * = unpack all elements from 'Target'
ax.legend(*scatter.legend_elements(), title='Target');

ax.axhline(over_50['chol'].mean(),
           linestyle='--');

# %%
# sharex gets the x from the second axes so the labels is only at the end
fig, (ax0, ax1) = plt.subplots(figsize=(10,10),
                               nrows=2,
                               ncols=1,
                               sharex=True)
fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold')

scatter = ax0.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target'])

ax0.set(title='Heart diseases and Cholesterol Levels',
       ylabel='Cholesterol')

ax0.legend(*scatter.legend_elements(), title='Target')

ax0.axhline(y=over_50['chol'].mean(),
           linestyle='--');

scatter1 = ax1.scatter(x=over_50['age'],
                    y=over_50['thalach'],
                    c=over_50['target'])

ax1.set(title='Heart Diseases 2',
       xlabel='Age',
       ylabel='Max heart rate')

ax1.axhline(y=over_50['thalach'].mean(),
           linestyle='--');

# %%
# Axis 0, 1 (row 0, column 0)
test_bg()

fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, figsize=(10, 10))
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"],
                      cmap='winter')
ax0.set(title="Heart Disease and Cholesterol Levels",
        xlabel="Age",
        ylabel="Cholesterol")

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(), 
            color='r', 
            linestyle='--', 
            label="Average");
ax0.legend(*scatter.legend_elements(), title="Target")

# Axis 1, 1 (row 1, column 1)
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"],
                      cmap='winter')
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate")

# Set the y axis
ax1.set_ylim([60, 200])

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(), 
            color='r', 
            linestyle='--', 
            label="Average");
ax1.legend(*scatter.legend_elements(), title="Target")

# Title the figure
fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold');

# %%
# Potential function

def plotting_workflow(data):
    # 1. Manipulate data
    
    # 2. Create plot
    
    # 3. Plot data
    
    # 4. Customize plot
    
    # 5. Save plot
    
    # 6. Return plot
    
    return plot

# %%
def dark_bg():
    plt.style.use('dark_background')
    COLOR = 'white'
    plt.rcParams['text.color'] = COLOR
    plt.rcParams['axes.labelcolor'] = COLOR
    plt.rcParams['xtick.color'] = COLOR
    plt.rcParams['ytick.color'] = COLOR
    return

# %%
def solarite_bg():
    plt.style.use('Solarize_Light2')
    COLOR = 'black'
    plt.rcParams['text.color'] = COLOR
    plt.rcParams['axes.labelcolor'] = COLOR
    plt.rcParams['xtick.color'] = COLOR
    plt.rcParams['ytick.color'] = COLOR
    return

# %%
def test_bg():
    from matplotlib import cycler
    colors = cycler('color',
                    ['#EE6666', '#3388BB', '#9988DD',
                     '#EECC55', '#88BB44', '#FFBBBB'])
    plt.rc('axes', facecolor='#E6E6E6', edgecolor='none',
           axisbelow=True, grid=True, prop_cycle=colors)
    plt.rc('grid', color='w', linestyle='solid')
    plt.rc('xtick', direction='out', color='gray')
    plt.rc('ytick', direction='out', color='gray')
    plt.rc('patch', edgecolor='#E6E6E6')
    plt.rc('lines', linewidth=2)
    return

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, figsize=(10, 10))
scatter = ax0.scatter(DATA[""], 
                      DATA[""], 
                      c=DATA[""],
                      cmap='winter')
ax0.set(title="",
        xlabel="",
        ylabel="")

# Set the X axis
ax0.set_xlim([50, 80])

# Setup a mean line
ax0.axhline(y=DATA[""].mean(), 
            color='r', 
            linestyle='--', 
            label="Average");
ax0.legend(*scatter.legend_elements(), title="DATA")

# Axis 1, 1 (row 1, column 1)
scatter = ax1.scatter(DATA[""], 
                      DATA[""], 
                      c=DATA[""],
                      cmap='Set2')
ax1.set(title="",
        xlabel="",
        ylabel="")

# Set the y axis
ax1.set_ylim([60, 200])

# Setup a mean line
ax1.axhline(y=DATA[""].mean(), 
            color='r', 
            linestyle='--', 
            label="Average");
ax1.legend(*scatter.legend_elements(), title="DATA")

# Title the figure
fig.suptitle('', fontsize=16, fontweight='bold');
